# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
import pickle
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.shape
#(rows, columns)
# Out:
# (569, 33)

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df=df.drop(['Unnamed: 32'], axis=1)#1=vertical
#0=horizontal

# %%
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
diabetes_test = pd.read_csv('test.csv')
diabetes_output = pd.read_csv('output.csv')

# %%
diabetes_test
# Out:
#     radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0         12.40         17.68           81.47      467.8          0.10540
# 1         11.81         17.39           75.27      428.9          0.10070
# 2         15.00         15.51           97.45      684.5          0.08371
# 3         11.51         23.93           74.52      403.5          0.09261
# 4         12.62         23.97           81.35      496.4          0.07903
# 5         14.90         22.53          102.10      685.0          0.09947
# 6         15.22         30.62          103.40      716.9          0.10480
# 7         13.54         14.36           87.46      566.3          0.09779
# 8         12.72         17.67           80.98      501.3          0.07896
# 9         17.05         19.08          113.40      895.0          0.11410
# 10        12.83         22.33           85.26      503.2          0.10880
# 11        11.20         29.37           70.67      386.0          0.07449
# ...

# %%
diagnosis= {
    'M': 1,
    'B': 0
}

# %%
X = df.iloc[:, 2:32] #Input Variables
y = df.iloc[:, 1] # Diagnosis

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(
    X,
    y, 
    test_size=0.2,
)

# %%
#Evaluation and Hyperparameter Tuning - Scaling the Data
from sklearn import preprocessing
from sklearn.datasets import make_classification
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

x_var, y_var = make_classification(random_state=42)
model_adj = make_pipeline(StandardScaler(), linear_model.LogisticRegression())
model_adj.fit(X_train, y_train)  # apply scaling on training data
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
best=0.98

# %%
for _ in range(10000):
    X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(
        X,
        y, 
        test_size=0.2,
    )
    linear=linear_model.LogisticRegression(max_iter=3000)
    linear.fit(X_train, y_train)
    acc=linear.score(X_test, y_test)
    print(acc)
    if acc>best:
        best=acc
        with open("New_Model.pickle", "wb") as f: #saving the model (name of file)
            pickle.dump(linear, f)
        print("Best Accuracy:",acc)
        break
# Out:
# 0.956140350877193
# 0.9736842105263158
# 0.9210526315789473
# 0.956140350877193
# 0.956140350877193
# 0.956140350877193
# 0.9385964912280702
# 0.956140350877193
# 0.9473684210526315
# 0.9473684210526315
# 0.956140350877193
# C:\Users\bataa\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9473684210526315
# 0.9298245614035088
# 0.9210526315789473
# 0.9736842105263158
# 0.9298245614035088
# 0.956140350877193
# 0.9385964912280702
# 0.9649122807017544
# 0.9385964912280702
# 0.956140350877193
# 0.9210526315789473
# ...

# %%
y_pred = linear.predict(diabetes_test)

output = [diabetes_output, y_pred[0:19]]
output
# Out:
# [    id  diagnosis
#  0    1        NaN
#  1    2        NaN
#  2    3        NaN
#  3    4        NaN
#  4    5        NaN
#  5    6        NaN
#  6    7        NaN
#  7    8        NaN
#  8    9        NaN
#  9   10        NaN
#  10  11        NaN
#  11  12        NaN
#  12  13        NaN
#  13  14        NaN
#  14  15        NaN
#  15  16        NaN
#  16  17        NaN
#  17  18        NaN
#  18  19        NaN
#  19  20        NaN,
#  array(['B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#         'B', 'M', 'M', 'M', 'M', 'M'], dtype=object)]

# %%
y_pred
# Out:
# array(['B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'M', 'M', 'M', 'M'], dtype=object)
